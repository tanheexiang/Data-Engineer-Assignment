# %%
import pandas as pd
import numpy as np
file_name = 'C:/Users/b2tanhe/Desktop/Sales_Transactions_Dataset_Weekly.csv'

df = pd.read_csv(file_name)
df.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8      ...        \
# 0           P1  11  12  10   8  13  12  14  21   6      ...
# 1           P2   7   6   3   2   7   1   6   3   3      ...
# 2           P3   7  11   8   9  10   8   7  13  12      ...
# 3           P4  12   8  13   5   9   6   9  13  13      ...
# 4           P5   8   5  13  11   6   7   9  14   9      ...
#
#    Normalized 42  Normalized 43  Normalized 44  Normalized 45  Normalized 46  \
# 0           0.06           0.22           0.28           0.39           0.50
# 1           0.20           0.40           0.50           0.10           0.10
# 2           0.27           1.00           0.18           0.18           0.36
# 3           0.41           0.47           0.06           0.12           0.24
# 4           0.27           0.53           0.27           0.60           0.20
#
#    Normalized 47  Normalized 48  Normalized 49  Normalized 50  Normalized 51
# ...

# %%
#Only select column 'Product_Code' and the 52 weeks columns for further processing

new_df = df.iloc[:,:53]
print(new_df)
# Out:
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W42  W43  W44  W45  \
# 0             P1  11  12  10   8  13  12  14  21   6 ...     4    7    8   10
# 1             P2   7   6   3   2   7   1   6   3   3 ...     2    4    5    1
# 2             P3   7  11   8   9  10   8   7  13  12 ...     6   14    5    5
# 3             P4  12   8  13   5   9   6   9  13  13 ...     9   10    3    4
# 4             P5   8   5  13  11   6   7   9  14   9 ...     7   11    7   12
# 5             P6   3   3   2   7   6   3   8   6   6 ...     4    2    4    3
# 6             P7   4   8   3   7   8   7   2   3  10 ...     2    3    3    6
# 7             P8   8   6  10   9   6   8   7   5  10 ...    10   14    4    8
# 8             P9  14   9  10   7  11  15  12   7  13 ...    11    5   13    3
# 9            P10  22  19  19  29  20  16  26  20  24 ...    14   17   11   24
# 10           P11  15   7  15  14  17   7  10  16  11 ...    11   16   12   11
# ...

# %%
#Sum all the number of sales for 52 weeks of all products

columns = ['W'+str(i) for i in range(0, 52)]

total_df = new_df[columns].sum(axis=1)

print(total_df)
# Out:
# 0       501
# 1       207
# 2       452
# 3       430
# 4       440
# 5       220
# 6       213
# 7       450
# 8       539
# 9      1010
# 10      601
# 11      203
# 12      470
# 13      615
# 14     1805
# 15     1875
# 16     1765
# 17     1682
# 18     1687
# 19      465
# 20      462
# 21      487
# 22      215
# 23     1877
# 24     1602
# 25      535
# 26     1804
# 27     1696
# 28      628
# 29     1690
#        ...
# 781     126
# 782     287
# 783      74
# 784     157
# 785      34
# 786      23
# 787     173
# 788     153
# 789     119
# 790     251
# 791      76
# 792     150
# 793      38
# 794     185
# 795     152
# 796     138
# 797     269
# 798      68
# 799     162
# 800      40
# 801      20
# 802     184
# 803      80
# 804     122
# 805     266
# 806      23
# 807     142
# 808      26
# 809      17
# 810      16
# Length: 811, dtype: int64

# %%
# Get the max value of all the total sales of all products

total_df.max()
# Out:
# 2220

# %%
#Identify the index position of the highest sales product

total_df.idxmax(axis=0)
# Out:
# 406

# %%
#Locate the product based on the index position

best_product = df.iloc[[total_df.idxmax(axis=0)]] 

print('Best performing product is', best_product['Product_Code'])
# Out:
# Best performing product is 406    P409
# Name: Product_Code, dtype: object

# %%
#Question 2c
#Define promising products as the top 5% highest selling products
#Start by sorting the total sum of all the products

sorted_df = total_df.sort_values(axis=0, ascending=False)

print(sorted_df)
# Out:
# 406    2220
# 33     1932
# 177    1925
# 134    1920
# 42     1913
# 189    1912
# 178    1904
# 172    1897
# 91     1896
# 136    1894
# 37     1892
# 173    1886
# 23     1877
# 15     1875
# 39     1864
# 53     1860
# 135    1859
# 192    1859
# 36     1858
# 190    1854
# 179    1853
# 100    1849
# 35     1843
# 65     1842
# 133    1841
# 74     1835
# 128    1832
# 127    1825
# 174    1824
# 62     1823
#        ...
# 641       2
# 229       2
# 649       2
# 644       2
# 703       2
# 642       2
# 227       2
# 425       2
# 468       2
# 651       2
# 465       2
# 464       2
# 249       2
# 252       2
# 418       2
# 715       2
# 754       2
# 278       2
# 379       2
# 380       2
# 381       2
# 751       2
# 675       1
# 214       1
# 679       1
# 466       1
# 258       1
# 253       1
# 714       1
# 250       1
# Length: 811, dtype: int64

# %%
pd.qcut(sorted_df, [0.95])
print(pd.qcut(sorted_df, [0.95]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-5e70d4834b3c> in <module>()
# ----> 1 pd.qcut(sorted_df, [0.95])
#       2 print(pd.qcut(sorted_df, [0.95]))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     204     fac, bins = _bins_to_cuts(x, bins, labels=labels,
#     205                               precision=precision, include_lowest=True,
# --> 206                               dtype=dtype, duplicates=duplicates)
#     207
#     208     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     247             labels = _format_labels(bins, precision, right=right,
# ...
