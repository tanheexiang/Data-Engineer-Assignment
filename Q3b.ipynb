# %%
import pandas
file_name = 'C:/Users/b2tanhe/Desktop/data job posts.csv'
colnames = ['jobpost', 'Duration', 'Location', 'JobDescription', 'JobRequirment', 'RequiredQual', 'Salary', 'Deadline',  'AboutC']

data = pandas.read_csv(file_name, names=colnames)

print(data)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              jobpost  \
# ...
